# %%
import pandas as pd
from evidently.dashboard import Dashboard
from evidently.tabs import DataDriftTab, CatTargetDriftTab
from evidently.model_profile import Profile
from evidently.profile_sections import DataDriftProfileSection
# Out:
# e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\analyzers\__init__.py:3: UserWarning: analyzers are deprecated, use metrics instead
#   warnings.warn("analyzers are deprecated, use metrics instead")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from evidently.dashboard import Dashboard
#       3 from evidently.tabs import DataDriftTab, CatTargetDriftTab
#       4 from evidently.model_profile import Profile
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\dashboard\__init__.py:6
#       1 #!/usr/bin/env python
#       2 # coding: utf-8
#       4 import warnings
# ----> 6 from .dashboard import Dashboard
#       8 warnings.warn("dashboards are deprecated, use metrics instead")
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\dashboard\dashboard.py:17
#      13 from typing import Tuple
#      15 import pandas
# ---> 17 from evidently.dashboard.tabs.base_tab import Tab
#      18 from evidently.model.dashboard import DashboardInfo
#      19 from evidently.model.widget import AdditionalGraphInfo
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\dashboard\tabs\__init__.py:4
#       1 #!/usr/bin/env python
#       2 # coding: utf-8
# ----> 4 from .cat_target_drift_tab import CatTargetDriftTab
#       5 from .classification_performance_tab import ClassificationPerformanceTab
#       6 from .data_drift_tab import DataDriftTab
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\dashboard\tabs\cat_target_drift_tab.py:3
#       1 #!/usr/bin/env python
#       2 # coding: utf-8
# ----> 3 from evidently.dashboard.tabs.base_tab import Tab
#       4 from evidently.dashboard.tabs.base_tab import Verbose
#       5 from evidently.dashboard.widgets.cat_output_drift_widget import CatOutputDriftWidget
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\dashboard\tabs\base_tab.py:12
#       8 from typing import Union
#      10 import pandas
# ---> 12 from evidently.analyzers.base_analyzer import Analyzer
#      13 from evidently.dashboard.widgets.widget import Widget
#      14 from evidently.model.widget import BaseWidgetInfo
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\analyzers\base_analyzer.py:9
#       5 from typing import Optional
#       7 import pandas as pd
# ----> 9 from evidently.metric_results import DatasetColumns
#      10 from evidently.options import OptionsProvider
#      11 from evidently.pipeline.column_mapping import ColumnMapping
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\metric_results.py:10
#       7 import numpy as np
#       8 import pandas as pd
# ---> 10 from evidently.base_metric import MetricResult
#      11 from evidently.base_metric import MetricResultField
#      12 from evidently.pipeline.column_mapping import TargetNames
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\base_metric.py:22
#      19 from pydantic import BaseConfig
#      20 from pydantic import BaseModel
# ---> 22 from evidently.features.generated_features import GeneratedFeature
#      23 from evidently.pipeline.column_mapping import ColumnMapping
#      24 from evidently.utils.data_preprocessing import DataDefinition
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\features\generated_features.py:7
#       3 from typing import Optional
#       5 import pandas as pd
# ----> 7 from evidently.utils.data_preprocessing import DataDefinition
#      10 class GeneratedFeature:
#      11     """
#      12     Class for computation of additional features.
#      13     """
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\utils\__init__.py:1
# ----> 1 from .numpy_encoder import NumpyEncoder
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\evidently\utils\numpy_encoder.py:26
#       5 import pandas as pd
#       7 from evidently.utils.types import ApproxValue
#       9 _TYPES_MAPPING = (
#      10     (
#      11         (
#      12             np.int_,
#      13             np.intc,
#      14             np.intp,
#      15             np.int8,
#      16             np.int16,
#      17             np.int32,
#      18             np.int64,
#      19             np.uint8,
#      20             np.uint16,
#      21             np.uint32,
#      22             np.uint64,
#      23         ),
#      24         int,
#      25     ),
# ---> 26     ((np.float_, np.float16, np.float32, np.float64), float),
#      27     ((np.ndarray,), lambda obj: obj.tolist()),
#      28     ((np.bool_), bool),
#      29     ((pd.Timedelta,), str),
#      30     (
#      31         (np.void, type(pd.NaT)),
#      32         lambda obj: None,
#      33     ),  # should be before datetime as NaT is subclass of datetime.
#      34     ((pd.Timestamp, datetime.datetime, datetime.date), lambda obj: obj.isoformat()),
#      35     # map ApproxValue to json value
#      36     ((ApproxValue,), lambda obj: obj.as_dict()),
#      37 )
#      40 class NumpyEncoder(json.JSONEncoder):
#      41     """Numpy and Pandas data types to JSON types encoder"""
#
# File e:\Projects_main\ML_OPS\MLOps_US_Visa_project\.venv\Lib\site-packages\numpy\__init__.py:794, in __getattr__(attr)
#     791     raise AttributeError(__former_attrs__[attr], name=None)
#     793 if attr in __expired_attributes__:
# --> 794     raise AttributeError(
#     795         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     796         f"{__expired_attributes__[attr]}",
#     797         name=None
#     798     )
#     800 if attr == "chararray":
#     801     warnings.warn(
#     802         "`np.chararray` is deprecated and will be removed from "
#     803         "the main namespace in the future. Use an array with a string "
#     804         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.float_` was removed in the NumPy 2.0 release. Use `np.float64` instead.

# %% [markdown]
# Load out Boston data
